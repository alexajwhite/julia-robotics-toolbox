# %% [markdown]
# # Robotics Toolbox - Spatial Maths
#
# ## 3D Transformations
#
# To include and start running this library write the following code in the Julia terminal.

# %%
include("src/base/spatial_maths/transforms3d.jl")

# %% [markdown]
# This toolbox contains spatial maths functions in order to create and manipulate SO3 and SE3 transformation matrices.
# To create a basic rotation matrix use the following functions which allow rotation about the x, y, and z axis respectively.
